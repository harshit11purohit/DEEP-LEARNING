# %% [markdown]
# # Inferencing with Pretrained YOLO Models

# %%
# %pip install ultralytics
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.4.43  Python-3.11.9 torch-2.11.0+cpu CPU (11th Gen Intel Core i5-1135G7 @ 2.40GHz)
# Setup complete  (4 CPUs, 7.7 GB RAM, 334.7/475.8 GB disk)

# %% [markdown]
# ## Command Line Interface

# %% [markdown]
# [Explore YOLO Models](https://docs.ultralytics.com/tasks/detect/#models)

# %%
import cv2

def show_image(image_path):
    image = cv2.imread(image_path)
    
    if image is None:
        print("Error: Image not found!")
        return

    cv2.imshow("Image", image)
    cv2.waitKey(0)
    cv2.destroyAllWindows()

# %% [markdown]
# Nano Model

# %%
# Run inference on an image with YOLO11n
# insruction to run model on a specfic image

# !yolo predict model=yolo11n.pt source="https://images.pexels.com/photos/13872248/pexels-photo-13872248.jpeg"
# Out:
# Ultralytics 8.4.43  Python-3.11.9 torch-2.11.0+cpu CPU (11th Gen Intel Core i5-1135G7 @ 2.40GHz)
# YOLO11n summary (fused): 100 layers, 2,616,248 parameters, 0 gradients, 6.5 GFLOPs
#
# Found https://images.pexels.com/photos/13872248/pexels-photo-13872248.jpeg locally at pexels-photo-13872248.jpeg
# WARNING Image Read Error c:\Users\Jagdish singh\DEEP-LEARNING\Object_Detection\pexels-photo-13872248.jpeg
# Traceback (most recent call last):
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "c:\Users\Jagdish singh\jupyter311\Scripts\yolo.exe\__main__.py", line 7, in <module>
#   File "C:\Users\Jagdish singh\jupyter311\Lib\site-packages\ultralytics\cfg\__init__.py", line 1006, in entrypoint
#     getattr(model, mode)(**overrides)  # default args from model
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Jagdish singh\jupyter311\Lib\site-packages\ultralytics\engine\model.py", line 537, in predict
# ...

# %%
import cv2
import matplotlib.pyplot as plt

def show_image(image_path):
    image = cv2.imread(image_path)

    if image is None:
        print("Error: Image not found!")
        return

    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    plt.imshow(image)
    plt.axis("off")
    plt.show()

# %%
show_image(r'C:\Users\Jagdish singh\DEEP-LEARNING\Object_Detection\runs\detect\predict\pexels-photo-13872248.jpeg')

# %% [markdown]
# S Model

# %%
# Run inference on an image with YOLO11s
# !yolo predict model=yolo11s.pt source='https://images.pexels.com/photos/13872248/pexels-photo-13872248.jpeg'
# Out:
# ...
# Ultralytics 8.4.43  Python-3.11.9 torch-2.11.0+cpu CPU (11th Gen Intel Core i5-1135G7 @ 2.40GHz)
# YOLO11s summary (fused): 100 layers, 9,443,760 parameters, 0 gradients, 21.5 GFLOPs
#
# WARNING Download failure, retrying 1/3 https://images.pexels.com/photos/13872248/pexels-photo-13872248.jpeg... HTTP Error 403: Forbidden
# image 1/1 c:\Users\Jagdish singh\DEEP-LEARNING\Object_Detection\pexels-photo-13872248.jpeg: 448x640 6 persons, 1231.0ms
# Speed: 104.0ms preprocess, 1231.0ms inference, 543.8ms postprocess per image at shape (1, 3, 448, 640)
# Results saved to C:\Users\Jagdish singh\DEEP-LEARNING\Object_Detection\runs\detect\predict-2
#  Learn more at https://docs.ultralytics.com/modes/predict
# #=#=#
# ##O#-#
#                                                                            0.0%
#                                                                            1.1%
# #                                                                          2.8%
# ...

# %%
show_image(r'C:\Users\Jagdish singh\DEEP-LEARNING\Object_Detection\runs\detect\predict\pexels-photo-13872248.jpg')

# %% [markdown]
# M Model

# %%
# Run inference on an image with YOLO11m
# !yolo predict model=yolo11m.pt source='https://images.pexels.com/photos/13872248/pexels-photo-13872248.jpeg'
# Out:
# ...
# Ultralytics 8.4.43  Python-3.11.9 torch-2.11.0+cpu CPU (11th Gen Intel Core i5-1135G7 @ 2.40GHz)
# YOLO11m summary (fused): 125 layers, 20,091,712 parameters, 0 gradients, 68.0 GFLOPs
#
# Found https://images.pexels.com/photos/13872248/pexels-photo-13872248.jpeg locally at pexels-photo-13872248.jpeg
# image 1/1 c:\Users\Jagdish singh\DEEP-LEARNING\Object_Detection\pexels-photo-13872248.jpeg: 448x640 6 persons, 1086.8ms
# Speed: 11.3ms preprocess, 1086.8ms inference, 2.1ms postprocess per image at shape (1, 3, 448, 640)
# Results saved to C:\Users\Jagdish singh\DEEP-LEARNING\Object_Detection\runs\detect\predict-4
#  Learn more at https://docs.ultralytics.com/modes/predict

# %%
show_image(r'C:\Users\Jagdish singh\DEEP-LEARNING\Object_Detection\runs\detect\predict-3\pexels-photo-13872248.jpg')

# %% [markdown]
# L Model

# %%
# Run inference on an image with YOLO11l
# !yolo predict model=yolo11l.pt source='https://images.pexels.com/photos/13872248/pexels-photo-13872248.jpeg'
# Out:
# ...
# Ultralytics 8.4.43  Python-3.11.9 torch-2.11.0+cpu CPU (11th Gen Intel Core i5-1135G7 @ 2.40GHz)
# YOLO11l summary (fused): 190 layers, 25,340,992 parameters, 0 gradients, 86.9 GFLOPs
#
# Found https://images.pexels.com/photos/13872248/pexels-photo-13872248.jpeg locally at pexels-photo-13872248.jpeg
# image 1/1 c:\Users\Jagdish singh\DEEP-LEARNING\Object_Detection\pexels-photo-13872248.jpeg: 448x640 6 persons, 1248.6ms
# Speed: 8.0ms preprocess, 1248.6ms inference, 2.3ms postprocess per image at shape (1, 3, 448, 640)
# Results saved to C:\Users\Jagdish singh\DEEP-LEARNING\Object_Detection\runs\detect\predict-5
#  Learn more at https://docs.ultralytics.com/modes/predict

# %%
show_image(r'C:\Users\Jagdish singh\DEEP-LEARNING\Object_Detection\runs\detect\predict-5\pexels-photo-13872248.jpg')

# %% [markdown]
# X Model

# %%
# Run inference on an image with YOLO11x
# !yolo predict model=yolo11x.pt source='https://images.pexels.com/photos/13872248/pexels-photo-13872248.jpeg'
# Out:
# ...
# ...
# ...
# Ultralytics 8.4.43  Python-3.11.9 torch-2.11.0+cpu CPU (11th Gen Intel Core i5-1135G7 @ 2.40GHz)
# YOLO11x summary (fused): 190 layers, 56,919,424 parameters, 0 gradients, 194.9 GFLOPs
#
# Found https://images.pexels.com/photos/13872248/pexels-photo-13872248.jpeg locally at pexels-photo-13872248.jpeg
# image 1/1 c:\Users\Jagdish singh\DEEP-LEARNING\Object_Detection\pexels-photo-13872248.jpeg: 448x640 6 persons, 1 bottle, 2215.8ms
# Speed: 15.4ms preprocess, 2215.8ms inference, 2.4ms postprocess per image at shape (1, 3, 448, 640)
# Results saved to C:\Users\Jagdish singh\DEEP-LEARNING\Object_Detection\runs\detect\predict-6
#  Learn more at https://docs.ultralytics.com/modes/predict

# %%
show_image(r'C:\Users\Jagdish singh\DEEP-LEARNING\Object_Detection\runs\detect\predict-6\pexels-photo-13872248.jpg')
